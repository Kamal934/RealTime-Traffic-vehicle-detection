# %%
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
! pip install ultralytics

# %%
# !pip install -q kaggle

# %%
! mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600  ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d saumyapatel/traffic-vehicles-object-detection
# Out:
# ...
# 100% 605M/607M [00:07<00:00, 85.0MB/s]
# 100% 607M/607M [00:07<00:00, 85.4MB/s]

# %%
# !unzip traffic-vehicles-object-detection.zip
# !rm -rf traffic-vehicles-object-detection.zip
# Out:
# Archive:  traffic-vehicles-object-detection.zip
#   inflating: Traffic Dataset/images/test/00 (1).png
#   inflating: Traffic Dataset/images/test/00 (10).png
#   inflating: Traffic Dataset/images/test/00 (100).png
#   inflating: Traffic Dataset/images/test/00 (11).png
#   inflating: Traffic Dataset/images/test/00 (12).png
#   inflating: Traffic Dataset/images/test/00 (13).png
#   inflating: Traffic Dataset/images/test/00 (14).png
#   inflating: Traffic Dataset/images/test/00 (15).png
#   inflating: Traffic Dataset/images/test/00 (16).png
#   inflating: Traffic Dataset/images/test/00 (17).png
#   inflating: Traffic Dataset/images/test/00 (174).jpg
#   inflating: Traffic Dataset/images/test/00 (175).jpg
#   inflating: Traffic Dataset/images/test/00 (176).jpg
#   inflating: Traffic Dataset/images/test/00 (177).jpg
#   inflating: Traffic Dataset/images/test/00 (178).jpg
#   inflating: Traffic Dataset/images/test/00 (179).jpg
#   inflating: Traffic Dataset/images/test/00 (18).png
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.11.2 torch-2.2.0+cu121 CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# Setup complete ✅ (8 CPUs, 7.5 GB RAM, 62.4/97.2 GB disk)

# %%
# %cd /content/drive/MyDrive/yolov8-new_dataset
# Out:
# /content/drive/MyDrive/yolov8-new_dataset

# %%
from ultralytics import YOLO

from IPython.display import display,Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/Traffic_Dataset/data.yaml batch=32 epochs=20 imgsz=416 plots=True
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/yolov8-new_dataset
# Out:
# /content/drive/MyDrive/yolov8-new_dataset

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/yolov8-new_dataset/runs/detect/train7/weights/best.pt data=/content/Traffic_Dataset/data.yaml
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/Traffic_Dataset/labels/val.cache... 185 images, 1 backgrounds, 0 corrupt: 100% 185/185 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:14<00:00,  1.20s/it]
#                    all        185       1980      0.768      0.669      0.728      0.476
#                    Car        185       1061      0.849        0.9      0.932      0.737
#           Number Plate        185        174      0.776      0.615      0.715       0.38
#      Blur Number Plate        185        161      0.899      0.422      0.515      0.228
#            Two Wheeler        185        271      0.774      0.838      0.885      0.598
#                   Auto        185         94      0.734      0.606       0.62      0.298
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8-new_dataset/runs/detect/train7/weights/best.pt conf=0.5 source=/content/video.mp4
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/1 (1/1800) /content/video.mp4: 256x416 14 Cars, 2 Trucks, 167.7ms
# video 1/1 (2/1800) /content/video.mp4: 256x416 14 Cars, 2 Trucks, 9.3ms
# video 1/1 (3/1800) /content/video.mp4: 256x416 14 Cars, 1 Number Plate, 2 Trucks, 8.2ms
# video 1/1 (4/1800) /content/video.mp4: 256x416 14 Cars, 2 Trucks, 12.5ms
# video 1/1 (5/1800) /content/video.mp4: 256x416 14 Cars, 1 Number Plate, 2 Trucks, 11.4ms
# video 1/1 (6/1800) /content/video.mp4: 256x416 14 Cars, 2 Number Plates, 2 Trucks, 11.1ms
# video 1/1 (7/1800) /content/video.mp4: 256x416 14 Cars, 2 Number Plates, 2 Trucks, 10.2ms
# video 1/1 (8/1800) /content/video.mp4: 256x416 15 Cars, 2 Number Plates, 2 Trucks, 8.2ms
# video 1/1 (9/1800) /content/video.mp4: 256x416 15 Cars, 1 Number Plate, 2 Trucks, 12.4ms
# ...
